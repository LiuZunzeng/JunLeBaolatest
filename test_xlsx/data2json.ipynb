# %%
import pandas as pd
import random
from datetime import datetime

# %%
# 读取 Excel 文件
excel_file = pd.ExcelFile('../input_xlsx/data_template_v1.2.xlsx')

# 通过工作表名称读取
config_sheetname = "配置信息"
depots_sheetname = "仓库信息"
vehicleType_sheetname = "车型车辆信息"
orders_sheetname = "订单信息"
customer_sheetname = "客户信息"
tariff_sheetname = "承运商费率合同信息"

# %% [markdown]
# # config信息
#
# | 参数名                          | 含义                                         | 类型    | 举例  | 默认值 | 是否必须 |
# |------------------------------|--------------------------------------------|-------|-----|-----|------|
# | config                       | 可选配置字段                                    | object| -   | -   | 是    |
# | &emsp;DELIVERY_LOADING_SPEED  | 车辆装卸货速度（货量/分钟）                          | float | 1.5 | 无   | 是    |
# | &emsp;DELIVERY_STAY_MINUTE     | 最少停留时间（分钟）                               | float | 8.0 | 无   | 是    |
# | &emsp;ROS_VEHICLE_SPEED        | 车速（km/h）                                  | float | 50.0| 无   | 是    |
# | &emsp;ROS_SPLIT_ORDER          | 是否允许拆单，"Y"表示允许，"N"表示不允许                 | string| Y   | 无   | 是    |
# | &emsp;ROS_NORMAL_TEMPERATURE_RATIO | 冷藏车中常温订单最大占比                          | float | 0.90| 无   | 是    |

# %%
config_df = excel_file.parse(config_sheetname)

config_df.head(5)
# Out:
#    车辆最少停留时间（分钟）  卸货速度（吨/小时） 车辆是否返厂  车速（千米/小时）
# 0             8           2      否         50

# %%
config_df["卸货速度（吨/小时）"] = config_df["卸货速度（吨/小时）"].astype("float")
config_df["车辆最少停留时间（分钟）"] = config_df["车辆最少停留时间（分钟）"].astype("float")
config_df["车速（千米/小时）"] = config_df["车速（千米/小时）"].astype("float")

# %%
config = dict()
config["DELIVERY_LOADING_SPEED"] = config_df["卸货速度（吨/小时）"][0]//60
config["DELIVERY_STAY_MINUTE"] = config_df["车辆最少停留时间（分钟）"][0]
config["ROS_VEHICLE_SPEED"] = config_df["车速（千米/小时）"][0]
config["ROS_SPLIT_ORDER"] = "Y"
config["ROS_NORMAL_TEMPERATURE_RATIO"] = 0.99

# %%
config
# Out:
# {'DELIVERY_LOADING_SPEED': 0.0,
#  'DELIVERY_STAY_MINUTE': 8.0,
#  'ROS_VEHICLE_SPEED': 50.0,
#  'ROS_SPLIT_ORDER': 'Y',
#  'ROS_NORMAL_TEMPERATURE_RATIO': 0.99}

# %% [markdown]
# # depots信息
#
#
# | 参数名  | 含义 | 类型 | 举例 | 默认值 | 是否必须 |
# |---------|------|------|------|--------|----------|
# | depots  | 物流中心。现行程序将只使用第一个物流中心，其余物流中心将被忽略。 | array[object] | - | - | 是       |
# | &emsp;branchId     | 物流中心代码         | string  | WH01         | 无  | 是  |
# | &emsp;branchDescr  | 物流中心名称         | string  | 张江物流中心 | 无  | 是  |
# | &emsp;longitude    | 经度(东经为正，西经为负) | string  | 121.47390    | 无  | 是  |
# | &emsp;latitude     | 纬度（北纬为正-南纬为负） | string  | 31.22805     | 无  | 是  |
# | &emsp;notes        | 说明                 | string  | 仓库说明     | 无  | 是  |
# | &emsp;branch_status| 仓库是否可用，"1"代表可用，"0"代表不可用 | string | 1            | 无  | 是  |

# %%
depots_df = excel_file.parse(depots_sheetname)

depots_df.head(5)
# Out:
#      仓库名称       仓库地址  地址编号                仓库经纬度
# 0  永盛一期工厂  鹿泉区石铜路36号  R005  114.39982,37.974305

# %%
depots_df['仓库名称'] = depots_df['仓库名称'].astype("str")
depots_df['仓库地址'] = depots_df['仓库地址'].astype("str")
depots_df['地址编号'] = depots_df['地址编号'].astype("str")
depots_df['仓库经纬度'] = depots_df['仓库经纬度'].astype("str")

# 使用 str.split() 方法拆分
depots_df[['longitude', 'latitude']] = depots_df['仓库经纬度'].str.split(',', expand=True)

# %%
depots_list = list()
for index, depot_info in depots_df.iterrows():
    depot = dict()
    depot["branchId"] = depot_info["地址编号"]
    depot["branchDesr"] = depot_info["仓库名称"]
    depot["longitude"] = depot_info["longitude"]
    depot["latitude"] = depot_info["latitude"]
    depot["notes"] = "note"
    depot["brach_status"] = "1"
    depots_list.append(depot)

# %% [markdown]
# # dispatchZone信息

# %% [markdown]
# ## vehicleType

# %%
normal_vehicleType_df = excel_file.parse(vehicleType_sheetname)
Refrigerate_vehicleType_df = excel_file.parse(vehicleType_sheetname)
normal_vehicleType_df.head(5)
# Out:
#    车辆编号  所属承运商  车辆类型  最小载重（吨）  最大载重（吨）  最大容量（立方米）  车辆温控类型
# 0   NaN    NaN  9.6米       10     15.0         43     NaN
# 1   NaN    NaN  6.8米        6      9.5         28     NaN
# 2   NaN    NaN  4.2米        2      6.0         15     NaN
# 3   NaN    NaN   15米       20     25.0         63     NaN

# %%
normal_vehicleType_df["车辆温控类型"] = "常温"
Refrigerate_vehicleType_df["车辆温控类型"] = "冷藏"
vehicleType_df = pd.concat([normal_vehicleType_df, Refrigerate_vehicleType_df], ignore_index=True)
vehicleType_df["车型编号"] = ['Type' + str(index+1) for index in vehicleType_df.index]

# %%
vehicleType_df["车辆类型"] = vehicleType_df["车辆类型"].astype("str")
vehicleType_df["最小载重（吨）"] = vehicleType_df["最小载重（吨）"].astype("float")
vehicleType_df["最大载重（吨）"] = vehicleType_df["最大载重（吨）"].astype("float")
vehicleType_df["最大容量（立方米）"] = vehicleType_df["最大容量（立方米）"].astype("float")

# %%
vehicleType_list = list()
for index, vehicleType_info in vehicleType_df.iterrows():
    vehicleType = dict()
    vehicleType["vehicleTypeId"] = vehicleType_info["车型编号"]
    vehicleType["vehicleTypeDescr1"] = vehicleType_info["车辆类型"]
    vehicleType["loadCapacityMin"] = vehicleType_info["最小载重（吨）"]
    vehicleType["loadCapacity"] = vehicleType_info["最大载重（吨）"]
    vehicleType["capacity"] = vehicleType_info["最大容量（立方米）"]
    vehicleType["temperatureType"] = vehicleType_info["车辆温控类型"]
    vehicleType_list.append(vehicleType)

# %%
vehicleType_list
# Out:
# [{'vehicleTypeId': 'Type1',
#   'vehicleTypeDescr1': '9.6米',
#   'loadCapacityMin': 10.0,
#   'loadCapacity': 15.0,
#   'capacity': 43.0,
#   'temperatureType': '常温'},
#  {'vehicleTypeId': 'Type2',
#   'vehicleTypeDescr1': '6.8米',
#   'loadCapacityMin': 6.0,
#   'loadCapacity': 9.5,
#   'capacity': 28.0,
#   'temperatureType': '常温'},
#  {'vehicleTypeId': 'Type3',
#   'vehicleTypeDescr1': '4.2米',
#   'loadCapacityMin': 2.0,
#   'loadCapacity': 6.0,
#   'capacity': 15.0,
#   'temperatureType': '常温'},
#  {'vehicleTypeId': 'Type4',
#   'vehicleTypeDescr1': '15米',
#   'loadCapacityMin': 20.0,
#   'loadCapacity': 25.0,
#   'capacity': 63.0,
#   'temperatureType': '常温'},
#  {'vehicleTypeId': 'Type5',
#   'vehicleTypeDescr1': '9.6米',
#   'loadCapacityMin': 10.0,
#   'loadCapacity': 15.0,
#   'capacity': 43.0,
#   'temperatureType': '冷藏'},
#  {'vehicleTypeId': 'Type6',
#   'vehicleTypeDescr1': '6.8米',
#   'loadCapacityMin': 6.0,
#   'loadCapacity': 9.5,
#   'capacity': 28.0,
#   'temperatureType': '冷藏'},
#  {'vehicleTypeId': 'Type7',
#   'vehicleTypeDescr1': '4.2米',
#   'loadCapacityMin': 2.0,
#   'loadCapacity': 6.0,
#   'capacity': 15.0,
#   'temperatureType': '冷藏'},
#  {'vehicleTypeId': 'Type8',
#   'vehicleTypeDescr1': '15米',
#   'loadCapacityMin': 20.0,
#   'loadCapacity': 25.0,
#   'capacity': 63.0,
#   'temperatureType': '冷藏'}]

# %% [markdown]
# ## vheicle

# %%
# 定义山东车牌号的前缀
shandong_prefixes = ['鲁A', '鲁B', '鲁C', '鲁D', '鲁E', '鲁F', '鲁G', '鲁H', '鲁J', '鲁K', '鲁L', '鲁M', '鲁N', '鲁P', '鲁Q', '鲁R', '鲁S', '鲁U', '鲁V', '鲁W', '鲁X', '鲁Y']
# 初始化车辆 ID 起始编号
vehicle_id_start = 1
# 定义车辆类型列表
vehicle_types = [f'Type{i}' for i in range(1, 9)]
# 初始化结果列表
vehicle_list = []
# 为每种车辆类型生成 50 个车辆信息
for vehicle_type in vehicle_types:
    for _ in range(50):
        # 生成车辆 ID
        vehicle_id = f"VE{str(vehicle_id_start).zfill(10)}"
        vehicle_id_start += 1
        # 随机选择一个山东车牌号前缀
        license_plate_prefix = random.choice(shandong_prefixes)
        # 生成随机的车牌号后五位（这里简单用数字表示）
        license_plate_suffix = ''.join(random.choices('0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ', k=5))
        # 组合成完整的车牌号
        license_plate_no = license_plate_prefix + license_plate_suffix
        # 创建车辆信息字典
        vehicle_info = {
            "vehicleId": vehicle_id,
            "licensePlateNo": license_plate_no,
            "vehicleType": vehicle_type
        }
        # 将车辆信息字典添加到结果列表中
        vehicle_list.append(vehicle_info)

# %% [markdown]
# ## tariff

# %%
normal_tariff_df = excel_file.parse(tariff_sheetname)
Refrigerate_tariff_df = excel_file.parse(tariff_sheetname)
normal_tariff_df.head(5)
# Out:
#      项目        项目名称               线路    计价单位  结算点    线路编码     里程  冷藏报价  非冷藏报价  \
# 0   NaN         NaN              NaN     NaN  NaN     NaN    NaN   NaN    NaN
# 1  液奶干线  石家庄工厂发山东区域           石家庄-桓台  元/吨.公里   桓台  D02465  399.0  0.65   0.59
# 2   NaN         NaN        石家庄-桓台-青州  元/吨.公里   青州  D02466  465.0  0.65   0.59
# 3   NaN         NaN     石家庄-桓台-青州-安丘  元/吨.公里   安丘  D02467  551.0  0.60   0.54
# 4   NaN         NaN  石家庄-桓台-青州-安丘-高密  元/吨.公里   高密  D02468  623.0  0.50   0.45
#
#             物流商               合同协议编码  补充协议编码     合同开始时间     合同结束时间
# 0           NaN                  NaN     NaN        NaT        NaT
# 1  北京澳德物流有限责任公司  JLB-JT-202410-00098     NaN 2024-10-10 2026-09-30
# 2  北京澳德物流有限责任公司  JLB-JT-202410-00098     NaN 2024-10-10 2026-09-30
# 3  北京澳德物流有限责任公司  JLB-JT-202410-00098     NaN 2024-10-10 2026-09-30
# 4  北京澳德物流有限责任公司  JLB-JT-202410-00098     NaN 2024-10-10 2026-09-30

# %%
normal_tariff_df["运输温控方式"] = "常温"
normal_tariff_df = normal_tariff_df.iloc[1:,:].drop('冷藏报价', axis=1).rename(columns={'非冷藏报价': '单价'})
Refrigerate_tariff_df["运输温控方式"] = "冷藏"
Refrigerate_tariff_df = Refrigerate_tariff_df.iloc[1:,:].drop('非冷藏报价', axis=1).rename(columns={'冷藏报价': '单价'})
tariff_df = pd.concat([normal_tariff_df, Refrigerate_tariff_df], ignore_index=True)
tariff_df["计价基准"] = tariff_df['计价单位'].apply(lambda x: '吨公里' if x == '元/吨.公里' else None)
tariff_df["始发地地点"] = tariff_df['线路'].apply(lambda x: x.split('-')[0])
tariff_df["目的地地点"] = tariff_df['线路'].apply(lambda x: x.split('-')[-1])

# %%
shipper_location_info = {
    "石家庄": {"shipperProvince": "河北省", "shipperCity": "石家庄市", "shipperDistrict": ""},
}
consignee_location_info = {
    "桓台": {"consigneeProvince": "山东省", "consigneeCity": "淄博市", "consigneeDistrict": "桓台县"},
    "青州": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": "青州市"},
    "安丘": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": "安丘市"},
    "高密": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": "高密市"},
    "惠民": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "惠民县"},
    "高青": {"consigneeProvince": "山东省", "consigneeCity": "淄博市", "consigneeDistrict": "高青县"},
    "博兴": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "博兴县"},
    "济阳": {"consigneeProvince": "山东省", "consigneeCity": "济南市", "consigneeDistrict": "济阳区"},
    "济南": {"consigneeProvince": "山东省", "consigneeCity": "济南市", "consigneeDistrict": ""},
    "章丘": {"consigneeProvince": "山东省", "consigneeCity": "济南市", "consigneeDistrict": "章丘区"},
    "莱州": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "莱州市"},
    "招远": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "招远市"},
    "龙口": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "龙口市"},
    "蓬莱": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "蓬莱区"},
    "乐陵": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "乐陵市"},
    "即墨": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": "即墨区"},
    "临清": {"consigneeProvince": "山东省", "consigneeCity": "聊城市", "consigneeDistrict": "临清市"},
    "聊城": {"consigneeProvince": "山东省", "consigneeCity": "聊城市", "consigneeDistrict": ""},
    "肥城": {"consigneeProvince": "山东省", "consigneeCity": "泰安市", "consigneeDistrict": "肥城市"},
    "新泰": {"consigneeProvince": "山东省", "consigneeCity": "泰安市", "consigneeDistrict": "新泰市"},
    "蒙阴": {"consigneeProvince": "山东省", "consigneeCity": "临沂市", "consigneeDistrict": "蒙阴县"},
    "青岛": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": ""},
    "胶州": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": "胶州市"},
    "黄岛": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": "黄岛区"},
    "宁津": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "宁津县"},
    "庆云": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "庆云县"},
    "无棣": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "无棣县"},
    "沾化": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "沾化区"},
    "河口": {"consigneeProvince": "山东省", "consigneeCity": "东营市", "consigneeDistrict": "河口区"},
    "夏津": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "夏津县"},
    "高唐": {"consigneeProvince": "山东省", "consigneeCity": "聊城市", "consigneeDistrict": "高唐县"},
    "茌平": {"consigneeProvince": "山东省", "consigneeCity": "聊城市", "consigneeDistrict": "茌平区"},
    "长清": {"consigneeProvince": "山东省", "consigneeCity": "济南市", "consigneeDistrict": "长清区"},
    "泰安": {"consigneeProvince": "山东省", "consigneeCity": "泰安市", "consigneeDistrict": ""},
    "莱芜": {"consigneeProvince": "山东省", "consigneeCity": "济南市", "consigneeDistrict": "莱芜区"},
    "阳信": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "阳信县"},
    "滨州": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": ""},
    "利津": {"consigneeProvince": "山东省", "consigneeCity": "东营市", "consigneeDistrict": "利津县"},
    "广饶": {"consigneeProvince": "山东省", "consigneeCity": "东营市", "consigneeDistrict": "广饶县"},
    "东营": {"consigneeProvince": "山东省", "consigneeCity": "东营市", "consigneeDistrict": ""},
    "禹城": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "禹城市"},
    "齐河": {"consigneeProvince": "山东省", "consigneeCity": "德州市", "consigneeDistrict": "齐河县"},
    "淄博": {"consigneeProvince": "山东省", "consigneeCity": "淄博市", "consigneeDistrict": ""},
    "寿光": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": "寿光市"},
    "潍坊": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": ""},
    "昌邑": {"consigneeProvince": "山东省", "consigneeCity": "潍坊市", "consigneeDistrict": "昌邑市"},
    "威海": {"consigneeProvince": "山东省", "consigneeCity": "威海市", "consigneeDistrict": ""},
    "烟台": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": ""},
    "淄川": {"consigneeProvince": "山东省", "consigneeCity": "淄博市", "consigneeDistrict": "淄川区"},
    "邹平": {"consigneeProvince": "山东省", "consigneeCity": "滨州市", "consigneeDistrict": "邹平市"},
    "平度": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": "平度市"},
    "莱西": {"consigneeProvince": "山东省", "consigneeCity": "青岛市", "consigneeDistrict": "莱西市"},
    "莱阳": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "莱阳市"},
    "海阳": {"consigneeProvince": "山东省", "consigneeCity": "烟台市", "consigneeDistrict": "海阳市"}
}

# %%
tariff_df["合同协议编码"] = tariff_df["合同协议编码"].astype("str")
tariff_df["线路"] = tariff_df["线路"].astype("str")
tariff_df["运输方式"] = "整车运输"
tariff_df["始发地地点"] = tariff_df['线路'].apply(lambda x: x.split('-')[0])
tariff_df["目的地地点"] = tariff_df['线路'].apply(lambda x: x.split('-')[-1])
tariff_df["运输温控方式"] = tariff_df["运输温控方式"].astype("str")
tariff_df["里程"] = tariff_df["里程"].astype("float")
tariff_df["计价基准"] = tariff_df["计价基准"].astype("str")
tariff_df["单价"] = tariff_df["单价"].astype("float")

# %%
tariff_list = list()
for index, tariff_info in tariff_df.iterrows():
    tariff = dict()
    tariff["tariffID"] = tariff_info["合同协议编码"]
    tariff["offeringType"] = "运输方式"
    tariff["shipperProvince"] = shipper_location_info[tariff_info["始发地地点"]]["shipperProvince"]
    tariff["shipperCity"] = shipper_location_info[tariff_info["始发地地点"]]["shipperCity"]
    tariff["shipperDistrict"] = shipper_location_info[tariff_info["始发地地点"]]["shipperDistrict"]
    tariff["consigneeProvince"] = consignee_location_info[tariff_info["目的地地点"]]["consigneeProvince"]
    tariff["consigneeCity"] = consignee_location_info[tariff_info["目的地地点"]]["consigneeCity"]
    tariff["consigneeDistrict"] = consignee_location_info[tariff_info["目的地地点"]]["consigneeDistrict"]
    tariff["temperatureType"] = tariff_info["运输温控方式"]
    tariff["mileage"] = tariff_info["里程"]
    tariff["rateBase"] = tariff_info["计价基准"]
    tariff["initialRate"] = tariff_info["单价"]
    tariff_list.append(tariff)

# %%
customer_df = excel_file.parse(customer_sheetname)
customer_df.head(5)
# Out:
#    客户编码      客户名称  客户等级       客户允许的可用车型 客户允许卸货的时间窗口  最长送达时间(小时) 卸货周期（星期几可以收货）  \
# 0  A001    低温阳信润丰   NaN  4.2米、6.8米、9.6米  8:00-18:00   14.154167         周一-周日
# 1  A002   低温惠民君莱宝   NaN  4.2米、6.8米、9.6米  8:00-18:00   16.654167         周一-周日
# 2  A003  滨州宝莱纳一鲜奶   NaN  4.2米、6.8米、9.6米  8:00-18:00   16.654167         周一-周日
# 3  A004   低温滨州宝莱纳   NaN  4.2米、6.8米、9.6米  8:00-18:00   16.654167         周一-周日
# 4  A005   低温滨州宝莱纳   NaN  4.2米、6.8米、9.6米  8:00-18:00   16.654167         周一-周日
#
#         发货波次
# 0  3：00-7：00
# 1  3：00-7：00
# 2  3：00-7：00
# 3  3：00-7：00
# 4  3：00-7：00

# %%
customer_df["发货波次"] = customer_df["发货波次"].astype("str")
departureWave = ','.join(customer_df["发货波次"].unique())

# %%
dispatchZone_list = list()
dispatchZoneCodelist = ["DISZONE001"]
for dispathZoneCode in dispatchZoneCodelist:
    dispatchZone = dict()
    dispatchZone["dispatchZoneCode"] = dispathZoneCode
    dispatchZone["departureWave"] = departureWave
    dispatchZone["longitude"] = depots_list[0]["longitude"]
    dispatchZone["latitude"] = depots_list[0]["latitude"]
    dispatchZone["vehicleType"] = vehicleType_list
    dispatchZone["vehicle"] = vehicle_list
    dispatchZone["tariff"] = tariff_list
    dispatchZone_list.append(dispatchZone)

# %%
dispatchZone_list[0]
# Out:
# {'dispathZoneCode': 'DISZONE001',
#  'departureWave': '3：00-7：00',
#  'longitude': '114.39982',
#  'latitude': '37.974305',
#  'vehicleType': [{'vehicleTypeId': 'Type1',
#    'vehicleTypeDescr1': '9.6米',
#    'loadCapacityMin': 10.0,
#    'loadCapacity': 15.0,
#    'capacity': 43.0,
#    'temperatureType': '常温'},
#   {'vehicleTypeId': 'Type2',
#    'vehicleTypeDescr1': '6.8米',
#    'loadCapacityMin': 6.0,
#    'loadCapacity': 9.5,
#    'capacity': 28.0,
#    'temperatureType': '常温'},
#   {'vehicleTypeId': 'Type3',
#    'vehicleTypeDescr1': '4.2米',
#    'loadCapacityMin': 2.0,
#    'loadCapacity': 6.0,
#    'capacity': 15.0,
#    'temperatureType': '常温'},
#   {'vehicleTypeId': 'Type4',
#    'vehicleTypeDescr1': '15米',
#    'loadCapacityMin': 20.0,
#    'loadCapacity': 25.0,
#    'capacity': 63.0,
#    'temperatureType': '常温'},
#   {'vehicleTypeId': 'Type5',
#    'vehicleTypeDescr1': '9.6米',
#    'loadCapacityMin': 10.0,
#    'loadCapacity': 15.0,
#    'capacity': 43.0,
#    'temperatureType': '冷藏'},
#   {'vehicleTypeId': 'Type6',
#    'vehicleTypeDescr1': '6.8米',
#    'loadCapacityMin': 6.0,
#    'loadCapacity': 9.5,
#    'capacity': 28.0,
#    'temperatureType': '冷藏'},
#   {'vehicleTypeId': 'Type7',
#    'vehicleTypeDescr1': '4.2米',
#    'loadCapacityMin': 2.0,
#    'loadCapacity': 6.0,
#    'capacity': 15.0,
#    'temperatureType': '冷藏'},
#   {'vehicleTypeId': 'Type8',
#    'vehicleTypeDescr1': '15米',
#    'loadCapacityMin': 20.0,
#    'loadCapacity': 25.0,
#    'capacity': 63.0,
#    'temperatureType': '冷藏'}],
#  'vehicle': [{'vehicleId': 'VE0000000001',
#    'licensePlateNo': '鲁RTF6MC',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000002',
#    'licensePlateNo': '鲁HJCCAD',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000003',
#    'licensePlateNo': '鲁HC06M4',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000004',
#    'licensePlateNo': '鲁RJJM7L',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000005',
#    'licensePlateNo': '鲁B6004O',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000006',
#    'licensePlateNo': '鲁NC9904',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000007',
#    'licensePlateNo': '鲁C6ZKNR',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000008',
#    'licensePlateNo': '鲁PCFDRI',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000009',
#    'licensePlateNo': '鲁A8S16H',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000010',
#    'licensePlateNo': '鲁YFPX5V',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000011',
#    'licensePlateNo': '鲁WNJG11',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000012',
#    'licensePlateNo': '鲁AV7KRJ',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000013',
#    'licensePlateNo': '鲁NGQ9AO',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000014',
#    'licensePlateNo': '鲁CR9I5W',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000015',
#    'licensePlateNo': '鲁UECJUU',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000016',
#    'licensePlateNo': '鲁YIQWY2',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000017',
#    'licensePlateNo': '鲁UYPA86',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000018',
#    'licensePlateNo': '鲁RPS5D9',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000019',
#    'licensePlateNo': '鲁WPPWBI',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000020',
#    'licensePlateNo': '鲁FGJ655',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000021',
#    'licensePlateNo': '鲁QAHQFD',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000022',
#    'licensePlateNo': '鲁ETPJT8',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000023',
#    'licensePlateNo': '鲁EUMF50',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000024',
#    'licensePlateNo': '鲁CPTIQT',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000025',
#    'licensePlateNo': '鲁LXKIKC',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000026',
#    'licensePlateNo': '鲁PMUDDJ',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000027',
#    'licensePlateNo': '鲁VXA76B',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000028',
#    'licensePlateNo': '鲁P1AE5J',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000029',
#    'licensePlateNo': '鲁QNT6TB',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000030',
#    'licensePlateNo': '鲁BWNV26',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000031',
#    'licensePlateNo': '鲁CDHP5T',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000032',
#    'licensePlateNo': '鲁FQR3VZ',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000033',
#    'licensePlateNo': '鲁JQ7K37',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000034',
#    'licensePlateNo': '鲁D7DWL9',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000035',
#    'licensePlateNo': '鲁WJL702',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000036',
#    'licensePlateNo': '鲁UURISM',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000037',
#    'licensePlateNo': '鲁VJRU8A',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000038',
#    'licensePlateNo': '鲁HGAD5Q',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000039',
#    'licensePlateNo': '鲁EKM7QX',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000040',
#    'licensePlateNo': '鲁QE5Y88',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000041',
#    'licensePlateNo': '鲁B29TO2',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000042',
#    'licensePlateNo': '鲁L6MTBN',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000043',
#    'licensePlateNo': '鲁Y4HU1W',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000044',
#    'licensePlateNo': '鲁QT6K7X',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000045',
#    'licensePlateNo': '鲁ENSMQC',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000046',
#    'licensePlateNo': '鲁NA7UQN',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000047',
#    'licensePlateNo': '鲁W8LUYU',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000048',
#    'licensePlateNo': '鲁RJX5N0',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000049',
#    'licensePlateNo': '鲁VS2PBY',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000050',
#    'licensePlateNo': '鲁K7B0PJ',
#    'vehicleType': 'Type1'},
#   {'vehicleId': 'VE0000000051',
#    'licensePlateNo': '鲁J3R5Y3',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000052',
#    'licensePlateNo': '鲁SP2EM5',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000053',
#    'licensePlateNo': '鲁LA56T0',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000054',
#    'licensePlateNo': '鲁G26XOL',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000055',
#    'licensePlateNo': '鲁REP66A',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000056',
#    'licensePlateNo': '鲁V6QPQX',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000057',
#    'licensePlateNo': '鲁LYL8PB',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000058',
#    'licensePlateNo': '鲁AQGP8H',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000059',
#    'licensePlateNo': '鲁NODSPQ',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000060',
#    'licensePlateNo': '鲁S6A6K0',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000061',
#    'licensePlateNo': '鲁NIY7VQ',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000062',
#    'licensePlateNo': '鲁AD0UVD',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000063',
#    'licensePlateNo': '鲁X0I1W3',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000064',
#    'licensePlateNo': '鲁QE0G0F',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000065',
#    'licensePlateNo': '鲁EHG5KH',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000066',
#    'licensePlateNo': '鲁GCISBE',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000067',
#    'licensePlateNo': '鲁YAG7IL',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000068',
#    'licensePlateNo': '鲁JCM1FM',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000069',
#    'licensePlateNo': '鲁M16T2T',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000070',
#    'licensePlateNo': '鲁LVES4I',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000071',
#    'licensePlateNo': '鲁CLC7CF',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000072',
#    'licensePlateNo': '鲁VRQI2S',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000073',
#    'licensePlateNo': '鲁K4WCFD',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000074',
#    'licensePlateNo': '鲁GJSVFR',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000075',
#    'licensePlateNo': '鲁NEPWTZ',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000076',
#    'licensePlateNo': '鲁KX3ZD5',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000077',
#    'licensePlateNo': '鲁F927AR',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000078',
#    'licensePlateNo': '鲁UX0WOL',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000079',
#    'licensePlateNo': '鲁P8R8GB',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000080',
#    'licensePlateNo': '鲁VIZO85',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000081',
#    'licensePlateNo': '鲁RV80M8',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000082',
#    'licensePlateNo': '鲁U18XTY',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000083',
#    'licensePlateNo': '鲁SLCVA6',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000084',
#    'licensePlateNo': '鲁QSVONA',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000085',
#    'licensePlateNo': '鲁XISFX2',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000086',
#    'licensePlateNo': '鲁B3W2VY',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000087',
#    'licensePlateNo': '鲁FY06FM',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000088',
#    'licensePlateNo': '鲁SIWROD',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000089',
#    'licensePlateNo': '鲁GLXJSS',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000090',
#    'licensePlateNo': '鲁SP35E3',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000091',
#    'licensePlateNo': '鲁CZA8MM',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000092',
#    'licensePlateNo': '鲁QI2CGZ',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000093',
#    'licensePlateNo': '鲁FXGQ8R',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000094',
#    'licensePlateNo': '鲁U95G32',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000095',
#    'licensePlateNo': '鲁JI4D3N',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000096',
#    'licensePlateNo': '鲁YGYWOP',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000097',
#    'licensePlateNo': '鲁VMMG69',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000098',
#    'licensePlateNo': '鲁BO3MA0',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000099',
#    'licensePlateNo': '鲁L91FY7',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000100',
#    'licensePlateNo': '鲁HLYYUS',
#    'vehicleType': 'Type2'},
#   {'vehicleId': 'VE0000000101',
#    'licensePlateNo': '鲁UYLCLQ',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000102',
#    'licensePlateNo': '鲁QEOY81',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000103',
#    'licensePlateNo': '鲁L7KQ8U',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000104',
#    'licensePlateNo': '鲁SYTQXL',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000105',
#    'licensePlateNo': '鲁YS06YE',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000106',
#    'licensePlateNo': '鲁M3S1M7',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000107',
#    'licensePlateNo': '鲁SBKZP2',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000108',
#    'licensePlateNo': '鲁C70981',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000109',
#    'licensePlateNo': '鲁RW140Q',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000110',
#    'licensePlateNo': '鲁XO6HGM',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000111',
#    'licensePlateNo': '鲁RVKRFX',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000112',
#    'licensePlateNo': '鲁URVIZO',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000113',
#    'licensePlateNo': '鲁V872AP',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000114',
#    'licensePlateNo': '鲁N18OZW',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000115',
#    'licensePlateNo': '鲁CG91Y8',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000116',
#    'licensePlateNo': '鲁PSFWN4',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000117',
#    'licensePlateNo': '鲁U32VL5',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000118',
#    'licensePlateNo': '鲁YRI60K',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000119',
#    'licensePlateNo': '鲁ES041G',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000120',
#    'licensePlateNo': '鲁PAGX9N',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000121',
#    'licensePlateNo': '鲁F918TY',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000122',
#    'licensePlateNo': '鲁G9H0HL',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000123',
#    'licensePlateNo': '鲁UFF5Z3',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000124',
#    'licensePlateNo': '鲁D6RSPC',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000125',
#    'licensePlateNo': '鲁MIQUUY',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000126',
#    'licensePlateNo': '鲁WH1PEG',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000127',
#    'licensePlateNo': '鲁PNQ4WM',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000128',
#    'licensePlateNo': '鲁KKE4D1',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000129',
#    'licensePlateNo': '鲁FYTF3M',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000130',
#    'licensePlateNo': '鲁QVKPK3',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000131',
#    'licensePlateNo': '鲁PT95EP',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000132',
#    'licensePlateNo': '鲁NDPWT8',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000133',
#    'licensePlateNo': '鲁RAJ0NV',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000134',
#    'licensePlateNo': '鲁UFKL3Q',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000135',
#    'licensePlateNo': '鲁LVJRYP',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000136',
#    'licensePlateNo': '鲁HXTBQS',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000137',
#    'licensePlateNo': '鲁D9IKO4',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000138',
#    'licensePlateNo': '鲁H7QBNE',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000139',
#    'licensePlateNo': '鲁W8H75K',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000140',
#    'licensePlateNo': '鲁QUXMJM',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000141',
#    'licensePlateNo': '鲁BIOGBS',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000142',
#    'licensePlateNo': '鲁D77WMX',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000143',
#    'licensePlateNo': '鲁HWO2W8',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000144',
#    'licensePlateNo': '鲁DJZKDD',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000145',
#    'licensePlateNo': '鲁FCKVF2',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000146',
#    'licensePlateNo': '鲁YL1ZG0',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000147',
#    'licensePlateNo': '鲁F6Q0XU',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000148',
#    'licensePlateNo': '鲁LHOHOB',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000149',
#    'licensePlateNo': '鲁YVT76Q',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000150',
#    'licensePlateNo': '鲁L9DJ13',
#    'vehicleType': 'Type3'},
#   {'vehicleId': 'VE0000000151',
#    'licensePlateNo': '鲁AKWNM1',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000152',
#    'licensePlateNo': '鲁F2SCGJ',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000153',
#    'licensePlateNo': '鲁YZ69UE',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000154',
#    'licensePlateNo': '鲁QHO8Y5',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000155',
#    'licensePlateNo': '鲁L0LIAA',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000156',
#    'licensePlateNo': '鲁STPH6T',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000157',
#    'licensePlateNo': '鲁SXUVWA',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000158',
#    'licensePlateNo': '鲁GIMHGX',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000159',
#    'licensePlateNo': '鲁JKBRHN',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000160',
#    'licensePlateNo': '鲁KW2D8M',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000161',
#    'licensePlateNo': '鲁P0XJ28',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000162',
#    'licensePlateNo': '鲁COF46Z',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000163',
#    'licensePlateNo': '鲁BFZH4R',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000164',
#    'licensePlateNo': '鲁MQ70KO',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000165',
#    'licensePlateNo': '鲁NLUK0M',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000166',
#    'licensePlateNo': '鲁GZIJ14',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000167',
#    'licensePlateNo': '鲁AO5F4B',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000168',
#    'licensePlateNo': '鲁YEWOX0',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000169',
#    'licensePlateNo': '鲁Y2BMX6',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000170',
#    'licensePlateNo': '鲁Y4FVHA',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000171',
#    'licensePlateNo': '鲁EF139G',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000172',
#    'licensePlateNo': '鲁RWRJGS',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000173',
#    'licensePlateNo': '鲁XLLMIJ',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000174',
#    'licensePlateNo': '鲁UCVZIA',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000175',
#    'licensePlateNo': '鲁M0VCJS',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000176',
#    'licensePlateNo': '鲁A8WZ50',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000177',
#    'licensePlateNo': '鲁ULWYKF',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000178',
#    'licensePlateNo': '鲁KT23LJ',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000179',
#    'licensePlateNo': '鲁A4207P',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000180',
#    'licensePlateNo': '鲁AQ9S6O',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000181',
#    'licensePlateNo': '鲁EYOAXZ',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000182',
#    'licensePlateNo': '鲁H1GHUK',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000183',
#    'licensePlateNo': '鲁N9OR5Z',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000184',
#    'licensePlateNo': '鲁F5W4Z1',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000185',
#    'licensePlateNo': '鲁XD40B8',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000186',
#    'licensePlateNo': '鲁SELC25',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000187',
#    'licensePlateNo': '鲁QYVEWY',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000188',
#    'licensePlateNo': '鲁M8IL9H',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000189',
#    'licensePlateNo': '鲁KR36A0',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000190',
#    'licensePlateNo': '鲁C3JCRX',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000191',
#    'licensePlateNo': '鲁QLVK5T',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000192',
#    'licensePlateNo': '鲁MHBHME',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000193',
#    'licensePlateNo': '鲁E632DF',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000194',
#    'licensePlateNo': '鲁EXZIVK',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000195',
#    'licensePlateNo': '鲁SI9OI8',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000196',
#    'licensePlateNo': '鲁CJ5WA5',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000197',
#    'licensePlateNo': '鲁PCVECK',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000198',
#    'licensePlateNo': '鲁QZTTIX',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000199',
#    'licensePlateNo': '鲁MV5TVY',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000200',
#    'licensePlateNo': '鲁A48G9Z',
#    'vehicleType': 'Type4'},
#   {'vehicleId': 'VE0000000201',
#    'licensePlateNo': '鲁E22BHF',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000202',
#    'licensePlateNo': '鲁QG34XF',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000203',
#    'licensePlateNo': '鲁ADLC5G',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000204',
#    'licensePlateNo': '鲁J5Z2YZ',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000205',
#    'licensePlateNo': '鲁MJG94I',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000206',
#    'licensePlateNo': '鲁HA1WTR',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000207',
#    'licensePlateNo': '鲁PRX4TX',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000208',
#    'licensePlateNo': '鲁WGQOE8',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000209',
#    'licensePlateNo': '鲁MXWXJM',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000210',
#    'licensePlateNo': '鲁KZ3DPN',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000211',
#    'licensePlateNo': '鲁SH113W',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000212',
#    'licensePlateNo': '鲁FWVGM3',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000213',
#    'licensePlateNo': '鲁QZRU8N',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000214',
#    'licensePlateNo': '鲁MM404O',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000215',
#    'licensePlateNo': '鲁JP1MJ3',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000216',
#    'licensePlateNo': '鲁LQUT0L',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000217',
#    'licensePlateNo': '鲁WP0H94',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000218',
#    'licensePlateNo': '鲁LP5TMI',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000219',
#    'licensePlateNo': '鲁HWQ57G',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000220',
#    'licensePlateNo': '鲁MR46GD',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000221',
#    'licensePlateNo': '鲁WZC419',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000222',
#    'licensePlateNo': '鲁A4S0II',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000223',
#    'licensePlateNo': '鲁D5AOX3',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000224',
#    'licensePlateNo': '鲁N3K7EO',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000225',
#    'licensePlateNo': '鲁U0TLI4',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000226',
#    'licensePlateNo': '鲁F0SNHB',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000227',
#    'licensePlateNo': '鲁YZ4XHS',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000228',
#    'licensePlateNo': '鲁NEBRPD',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000229',
#    'licensePlateNo': '鲁QII0JU',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000230',
#    'licensePlateNo': '鲁NM4XHB',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000231',
#    'licensePlateNo': '鲁KHADTU',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000232',
#    'licensePlateNo': '鲁F8NC75',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000233',
#    'licensePlateNo': '鲁W6L3CJ',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000234',
#    'licensePlateNo': '鲁YAV0DQ',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000235',
#    'licensePlateNo': '鲁NVCYST',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000236',
#    'licensePlateNo': '鲁U3SSKB',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000237',
#    'licensePlateNo': '鲁Y1NCEY',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000238',
#    'licensePlateNo': '鲁QEF39J',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000239',
#    'licensePlateNo': '鲁WR0DZM',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000240',
#    'licensePlateNo': '鲁B9V59C',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000241',
#    'licensePlateNo': '鲁AZ9MCS',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000242',
#    'licensePlateNo': '鲁VZZE52',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000243',
#    'licensePlateNo': '鲁VCTT2M',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000244',
#    'licensePlateNo': '鲁VPHQE9',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000245',
#    'licensePlateNo': '鲁FQCXGV',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000246',
#    'licensePlateNo': '鲁LKHF13',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000247',
#    'licensePlateNo': '鲁JV8RG6',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000248',
#    'licensePlateNo': '鲁U4PX94',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000249',
#    'licensePlateNo': '鲁D3YQWF',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000250',
#    'licensePlateNo': '鲁FOH135',
#    'vehicleType': 'Type5'},
#   {'vehicleId': 'VE0000000251',
#    'licensePlateNo': '鲁W05LU3',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000252',
#    'licensePlateNo': '鲁XUHBR9',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000253',
#    'licensePlateNo': '鲁SIRPYJ',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000254',
#    'licensePlateNo': '鲁L943O2',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000255',
#    'licensePlateNo': '鲁CL20AQ',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000256',
#    'licensePlateNo': '鲁YAR6RS',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000257',
#    'licensePlateNo': '鲁DDZJ8R',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000258',
#    'licensePlateNo': '鲁MQM99N',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000259',
#    'licensePlateNo': '鲁R8MSCR',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000260',
#    'licensePlateNo': '鲁RLVZC1',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000261',
#    'licensePlateNo': '鲁M22NXE',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000262',
#    'licensePlateNo': '鲁WGE7VN',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000263',
#    'licensePlateNo': '鲁C6ZAN0',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000264',
#    'licensePlateNo': '鲁YK2URK',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000265',
#    'licensePlateNo': '鲁XYTXGW',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000266',
#    'licensePlateNo': '鲁SRAVTZ',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000267',
#    'licensePlateNo': '鲁ENICJF',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000268',
#    'licensePlateNo': '鲁D7GIGM',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000269',
#    'licensePlateNo': '鲁C93LUT',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000270',
#    'licensePlateNo': '鲁LBTONG',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000271',
#    'licensePlateNo': '鲁DMIVJP',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000272',
#    'licensePlateNo': '鲁GK5JMO',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000273',
#    'licensePlateNo': '鲁WR0X60',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000274',
#    'licensePlateNo': '鲁VCARNH',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000275',
#    'licensePlateNo': '鲁PNO6BF',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000276',
#    'licensePlateNo': '鲁S4AJWG',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000277',
#    'licensePlateNo': '鲁FKJ21F',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000278',
#    'licensePlateNo': '鲁WPTO9S',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000279',
#    'licensePlateNo': '鲁PVIL76',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000280',
#    'licensePlateNo': '鲁KIYPXM',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000281',
#    'licensePlateNo': '鲁DQZ4XT',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000282',
#    'licensePlateNo': '鲁RG8CCN',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000283',
#    'licensePlateNo': '鲁GD1QL1',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000284',
#    'licensePlateNo': '鲁FE0MCL',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000285',
#    'licensePlateNo': '鲁Q5QGIP',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000286',
#    'licensePlateNo': '鲁ET8QP3',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000287',
#    'licensePlateNo': '鲁XPJ39U',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000288',
#    'licensePlateNo': '鲁WAS7EZ',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000289',
#    'licensePlateNo': '鲁J6DCQW',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000290',
#    'licensePlateNo': '鲁YX5KBV',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000291',
#    'licensePlateNo': '鲁XPS1NO',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000292',
#    'licensePlateNo': '鲁WFRHAT',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000293',
#    'licensePlateNo': '鲁LZZJMM',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000294',
#    'licensePlateNo': '鲁MKOTYS',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000295',
#    'licensePlateNo': '鲁WWDNSS',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000296',
#    'licensePlateNo': '鲁RIESA0',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000297',
#    'licensePlateNo': '鲁KPFU6D',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000298',
#    'licensePlateNo': '鲁YFT0V5',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000299',
#    'licensePlateNo': '鲁U2BXMQ',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000300',
#    'licensePlateNo': '鲁NNH0JT',
#    'vehicleType': 'Type6'},
#   {'vehicleId': 'VE0000000301',
#    'licensePlateNo': '鲁HZE5L7',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000302',
#    'licensePlateNo': '鲁YFT1RK',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000303',
#    'licensePlateNo': '鲁CAC8DS',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000304',
#    'licensePlateNo': '鲁J2IVNZ',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000305',
#    'licensePlateNo': '鲁ELZ9LO',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000306',
#    'licensePlateNo': '鲁D709DV',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000307',
#    'licensePlateNo': '鲁WMLZZJ',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000308',
#    'licensePlateNo': '鲁D6P7W2',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000309',
#    'licensePlateNo': '鲁BJK1BR',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000310',
#    'licensePlateNo': '鲁L04ARE',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000311',
#    'licensePlateNo': '鲁D508R7',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000312',
#    'licensePlateNo': '鲁QBDMGZ',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000313',
#    'licensePlateNo': '鲁PM5239',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000314',
#    'licensePlateNo': '鲁AR2CXX',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000315',
#    'licensePlateNo': '鲁ED0JGF',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000316',
#    'licensePlateNo': '鲁S7KQ2B',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000317',
#    'licensePlateNo': '鲁VOX7WM',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000318',
#    'licensePlateNo': '鲁BJZGRC',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000319',
#    'licensePlateNo': '鲁B1DQTD',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000320',
#    'licensePlateNo': '鲁K2QLZL',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000321',
#    'licensePlateNo': '鲁GL6FZ5',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000322',
#    'licensePlateNo': '鲁FFPNYW',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000323',
#    'licensePlateNo': '鲁YLGUG5',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000324',
#    'licensePlateNo': '鲁K5EU80',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000325',
#    'licensePlateNo': '鲁YO3BNB',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000326',
#    'licensePlateNo': '鲁DENX6I',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000327',
#    'licensePlateNo': '鲁UZW8IE',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000328',
#    'licensePlateNo': '鲁VDML5K',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000329',
#    'licensePlateNo': '鲁PMCEIX',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000330',
#    'licensePlateNo': '鲁DBDC3H',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000331',
#    'licensePlateNo': '鲁GCQTZ4',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000332',
#    'licensePlateNo': '鲁P6UKRW',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000333',
#    'licensePlateNo': '鲁EX6CW6',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000334',
#    'licensePlateNo': '鲁CQU16D',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000335',
#    'licensePlateNo': '鲁GP6KNE',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000336',
#    'licensePlateNo': '鲁B7NITG',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000337',
#    'licensePlateNo': '鲁HJPSGK',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000338',
#    'licensePlateNo': '鲁C20BXO',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000339',
#    'licensePlateNo': '鲁QSSAXV',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000340',
#    'licensePlateNo': '鲁WRJ3JV',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000341',
#    'licensePlateNo': '鲁GQPIJ6',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000342',
#    'licensePlateNo': '鲁EA79YT',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000343',
#    'licensePlateNo': '鲁NV0F5O',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000344',
#    'licensePlateNo': '鲁DAS4ZK',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000345',
#    'licensePlateNo': '鲁VW7P4E',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000346',
#    'licensePlateNo': '鲁HD8FDM',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000347',
#    'licensePlateNo': '鲁KYA7RR',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000348',
#    'licensePlateNo': '鲁FGGBLX',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000349',
#    'licensePlateNo': '鲁PCS4ZF',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000350',
#    'licensePlateNo': '鲁JD5J12',
#    'vehicleType': 'Type7'},
#   {'vehicleId': 'VE0000000351',
#    'licensePlateNo': '鲁Y7IJP3',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000352',
#    'licensePlateNo': '鲁D172KB',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000353',
#    'licensePlateNo': '鲁N0RCVH',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000354',
#    'licensePlateNo': '鲁SYLWN7',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000355',
#    'licensePlateNo': '鲁ENWHCI',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000356',
#    'licensePlateNo': '鲁SL78FD',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000357',
#    'licensePlateNo': '鲁J1MG1X',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000358',
#    'licensePlateNo': '鲁PLSV5B',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000359',
#    'licensePlateNo': '鲁BSYLS3',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000360',
#    'licensePlateNo': '鲁WFZM98',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000361',
#    'licensePlateNo': '鲁QHIGVN',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000362',
#    'licensePlateNo': '鲁A4VVO4',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000363',
#    'licensePlateNo': '鲁CQJYYT',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000364',
#    'licensePlateNo': '鲁H8Q0FA',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000365',
#    'licensePlateNo': '鲁GKAO5I',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000366',
#    'licensePlateNo': '鲁PTDA3D',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000367',
#    'licensePlateNo': '鲁GPR9FZ',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000368',
#    'licensePlateNo': '鲁PG9YG1',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000369',
#    'licensePlateNo': '鲁JSR85L',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000370',
#    'licensePlateNo': '鲁Q7WRQ2',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000371',
#    'licensePlateNo': '鲁JDH14V',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000372',
#    'licensePlateNo': '鲁BJZUV3',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000373',
#    'licensePlateNo': '鲁K8K4N1',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000374',
#    'licensePlateNo': '鲁N32AXI',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000375',
#    'licensePlateNo': '鲁EJO8KU',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000376',
#    'licensePlateNo': '鲁DEHI0Z',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000377',
#    'licensePlateNo': '鲁H2NVFR',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000378',
#    'licensePlateNo': '鲁P8RLMX',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000379',
#    'licensePlateNo': '鲁BIKFIU',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000380',
#    'licensePlateNo': '鲁XH3IDO',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000381',
#    'licensePlateNo': '鲁R2JET7',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000382',
#    'licensePlateNo': '鲁SFTZMS',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000383',
#    'licensePlateNo': '鲁RHM3A5',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000384',
#    'licensePlateNo': '鲁H42NUP',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000385',
#    'licensePlateNo': '鲁PXKBQY',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000386',
#    'licensePlateNo': '鲁CO6KEW',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000387',
#    'licensePlateNo': '鲁EBGEIE',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000388',
#    'licensePlateNo': '鲁JCUM2K',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000389',
#    'licensePlateNo': '鲁KLFP9J',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000390',
#    'licensePlateNo': '鲁HTNCHZ',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000391',
#    'licensePlateNo': '鲁AH7LW9',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000392',
#    'licensePlateNo': '鲁C2M3UJ',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000393',
#    'licensePlateNo': '鲁Q71B27',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000394',
#    'licensePlateNo': '鲁GHQ902',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000395',
#    'licensePlateNo': '鲁MKCLVX',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000396',
#    'licensePlateNo': '鲁NZV0QC',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000397',
#    'licensePlateNo': '鲁JXEJ5P',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000398',
#    'licensePlateNo': '鲁X8L0ZQ',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000399',
#    'licensePlateNo': '鲁CBTPYF',
#    'vehicleType': 'Type8'},
#   {'vehicleId': 'VE0000000400',
#    'licensePlateNo': '鲁CL07GY',
#    'vehicleType': 'Type8'}],
#  'tariff': [{'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '淄博市',
#    'consigneeDistrict': '桓台县',
#    'temperatureType': '常温',
#    'mileage': 399.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '青州市',
#    'temperatureType': '常温',
#    'mileage': 465.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '安丘市',
#    'temperatureType': '常温',
#    'mileage': 551.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.54},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '高密市',
#    'temperatureType': '常温',
#    'mileage': 623.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '惠民县',
#    'temperatureType': '常温',
#    'mileage': 323.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '淄博市',
#    'consigneeDistrict': '高青县',
#    'temperatureType': '常温',
#    'mileage': 372.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '博兴县',
#    'temperatureType': '常温',
#    'mileage': 401.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '济阳区',
#    'temperatureType': '常温',
#    'mileage': 314.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '',
#    'temperatureType': '常温',
#    'mileage': 359.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.51},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '章丘区',
#    'temperatureType': '常温',
#    'mileage': 398.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '莱州市',
#    'temperatureType': '常温',
#    'mileage': 587.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '招远市',
#    'temperatureType': '常温',
#    'mileage': 653.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '龙口市',
#    'temperatureType': '常温',
#    'mileage': 705.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '蓬莱区',
#    'temperatureType': '常温',
#    'mileage': 757.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '乐陵市',
#    'temperatureType': '常温',
#    'mileage': 296.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '即墨区',
#    'temperatureType': '常温',
#    'mileage': 662.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '临清市',
#    'temperatureType': '常温',
#    'mileage': 192.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '',
#    'temperatureType': '常温',
#    'mileage': 286.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '泰安市',
#    'consigneeDistrict': '肥城市',
#    'temperatureType': '常温',
#    'mileage': 387.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '泰安市',
#    'consigneeDistrict': '新泰市',
#    'temperatureType': '常温',
#    'mileage': 506.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '临沂市',
#    'consigneeDistrict': '蒙阴县',
#    'temperatureType': '常温',
#    'mileage': 546.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '',
#    'temperatureType': '常温',
#    'mileage': 641.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '胶州市',
#    'temperatureType': '常温',
#    'mileage': 589.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '黄岛区',
#    'temperatureType': '常温',
#    'mileage': 634.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.41},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '宁津县',
#    'temperatureType': '常温',
#    'mileage': 255.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '乐陵市',
#    'temperatureType': '常温',
#    'mileage': 305.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '庆云县',
#    'temperatureType': '常温',
#    'mileage': 322.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '无棣县',
#    'temperatureType': '常温',
#    'mileage': 346.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '沾化区',
#    'temperatureType': '常温',
#    'mileage': 400.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.59},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
# ...
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '博兴县',
#    'temperatureType': '冷藏',
#    'mileage': 401.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '济阳区',
#    'temperatureType': '冷藏',
#    'mileage': 314.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 359.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.57},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '章丘区',
#    'temperatureType': '冷藏',
#    'mileage': 398.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '莱州市',
#    'temperatureType': '冷藏',
#    'mileage': 587.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '招远市',
#    'temperatureType': '冷藏',
#    'mileage': 653.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '龙口市',
#    'temperatureType': '冷藏',
#    'mileage': 705.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '蓬莱区',
#    'temperatureType': '冷藏',
#    'mileage': 757.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '乐陵市',
#    'temperatureType': '冷藏',
#    'mileage': 296.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '即墨区',
#    'temperatureType': '冷藏',
#    'mileage': 662.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '临清市',
#    'temperatureType': '冷藏',
#    'mileage': 192.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 286.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '泰安市',
#    'consigneeDistrict': '肥城市',
#    'temperatureType': '冷藏',
#    'mileage': 387.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '泰安市',
#    'consigneeDistrict': '新泰市',
#    'temperatureType': '冷藏',
#    'mileage': 506.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '临沂市',
#    'consigneeDistrict': '蒙阴县',
#    'temperatureType': '冷藏',
#    'mileage': 546.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 641.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.49},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '胶州市',
#    'temperatureType': '冷藏',
#    'mileage': 589.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.49},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '黄岛区',
#    'temperatureType': '冷藏',
#    'mileage': 634.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.49},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '宁津县',
#    'temperatureType': '冷藏',
#    'mileage': 255.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '乐陵市',
#    'temperatureType': '冷藏',
#    'mileage': 305.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '庆云县',
#    'temperatureType': '冷藏',
#    'mileage': 322.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '无棣县',
#    'temperatureType': '冷藏',
#    'mileage': 346.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '沾化区',
#    'temperatureType': '冷藏',
#    'mileage': 400.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '东营市',
#    'consigneeDistrict': '河口区',
#    'temperatureType': '冷藏',
#    'mileage': 468.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '夏津县',
#    'temperatureType': '冷藏',
#    'mileage': 198.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '高唐县',
#    'temperatureType': '冷藏',
#    'mileage': 224.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '聊城市',
#    'consigneeDistrict': '茌平区',
#    'temperatureType': '冷藏',
#    'mileage': 277.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.6},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '长清区',
#    'temperatureType': '冷藏',
#    'mileage': 343.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.65},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '泰安市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 408.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '济南市',
#    'consigneeDistrict': '莱芜区',
#    'temperatureType': '冷藏',
#    'mileage': 465.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '阳信县',
#    'temperatureType': '冷藏',
#    'mileage': 333.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.6},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 403.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '东营市',
#    'consigneeDistrict': '利津县',
#    'temperatureType': '冷藏',
#    'mileage': 439.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '东营市',
#    'consigneeDistrict': '广饶县',
#    'temperatureType': '冷藏',
#    'mileage': 543.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '东营市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 483.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '禹城市',
#    'temperatureType': '冷藏',
#    'mileage': 260.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.6},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '德州市',
#    'consigneeDistrict': '齐河县',
#    'temperatureType': '冷藏',
#    'mileage': 287.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.6},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '淄博市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 393.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '寿光市',
#    'temperatureType': '冷藏',
#    'mileage': 469.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.47},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 515.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.47},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '潍坊市',
#    'consigneeDistrict': '昌邑市',
#    'temperatureType': '冷藏',
#    'mileage': 548.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.47},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '威海市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 817.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '',
#    'temperatureType': '冷藏',
#    'mileage': 740.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '淄博市',
#    'consigneeDistrict': '淄川区',
#    'temperatureType': '冷藏',
#    'mileage': 391.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '滨州市',
#    'consigneeDistrict': '邹平市',
#    'temperatureType': '冷藏',
#    'mileage': 360.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '平度市',
#    'temperatureType': '冷藏',
#    'mileage': 572.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '青岛市',
#    'consigneeDistrict': '莱西市',
#    'temperatureType': '冷藏',
#    'mileage': 632.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.5},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '莱阳市',
#    'temperatureType': '冷藏',
#    'mileage': 657.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45},
#   {'tariffID': 'JLB-JT-202410-00098',
#    'offeringType': '运输方式',
#    'shipperProvince': '河北省',
#    'shipperCity': '石家庄市',
#    'shipperDistrict': '',
#    'consigneeProvince': '山东省',
#    'consigneeCity': '烟台市',
#    'consigneeDistrict': '海阳市',
#    'temperatureType': '冷藏',
#    'mileage': 719.0,
#    'rateBase': '吨公里',
#    'initialRate': 0.45}]}

# %% [markdown]
# # orders信息

# %%
orders_df = excel_file.parse(orders_sheetname)
customer_df = excel_file.parse(customer_sheetname)
customer_df = customer_df.rename(columns={"客户编码":"客户编号","维度":"纬度"})
orders_df = orders_df.rename(columns={"维度":"纬度"})
orders_df.head(5)
# Out:
#         订单编号  客户编号      地址编号  收货省 收货市  收货区                 目的地省市区详细地址  \
# 0  812834867  A001    低温阳信润丰  山东省  阳信  NaN  山东省滨州市阳信县信城街道办事处劳家小庄村中段路西
# 1  812835112  A002   低温惠民君莱宝  山东省  滨州  NaN      西20米 山东省滨州市滨城区北外环北海佲墅
# 2  812836451  A003  滨州宝莱纳一鲜奶  山东省  滨州  NaN      西20米 山东省滨州市滨城区北外环北海佲墅
# 3  812835124  A004   低温滨州宝莱纳  山东省  滨州  NaN      西20米 山东省滨州市滨城区北外环北海佲墅
# 4  812835866  A005   低温滨州宝莱纳  山东省  滨州  NaN      西20米 山东省滨州市滨城区北外环北海佲墅
#
#            经度         纬度 温控类型  订单总重量（吨）  订单总体积（立方米）
# 0  117.435735  37.627133   冷藏     2.737       7.368
# 1  117.985678  37.435452   冷藏     0.715       1.447
# 2  117.985678  37.435452   冷藏     0.679       1.275
# 3  117.985678  37.435452   冷藏     7.016      19.659
# 4  117.985678  37.435452   冷藏     0.004       0.004

# %%
order_c_df = pd.merge(orders_df, customer_df, on='客户编号', how='outer')

order_c_df["订单编号"] = order_c_df["订单编号"].astype("str")
order_c_df["创建时间"] = order_c_df.apply(lambda _: f"{datetime.now().strftime('%Y-%m-%d')}T{random.randint(0, 23):02d}:{random.randint(0, 59):02d}", axis=1)
order_c_df["温控类型"] = order_c_df["温控类型"].astype("str")
order_c_df['目的地省市区详细地址'] = order_c_df['目的地省市区详细地址'].astype("str")
encoded_values = pd.factorize(order_c_df['目的地省市区详细地址'])[0]

# 将编码值转换为指定格式
order_c_df["地址编码"] = ['DZ{:06d}'.format(val + 1) for val in encoded_values]

order_c_df["经度"] = order_c_df["经度"].astype("float")
order_c_df["纬度"] = order_c_df["纬度"].astype("float")
order_c_df["客户编号"] = order_c_df["客户编号"].astype("str")
order_c_df["客户允许的可用车型"] = order_c_df["客户允许的可用车型"].astype("str")
name_atr_to_code = {(vehicleType["vehicleTypeDescr1"],vehicleType["temperatureType"]): vehicleType["vehicleTypeId"] for vehicleType in vehicleType_list}

# 定义一个函数用于处理每行数据
def match_codes(row):
    names = row["客户允许的可用车型"].split('、')
    attrs = [row["温控类型"]]*len(names)
    codes = []
    for name, atr in zip(names, attrs):
        code = name_atr_to_code.get((name, atr))
        if code:
            codes.append(code)
    return ','.join(codes)
order_c_df["客户允许的可用车型编码"] = order_c_df.apply(match_codes, axis=1)
order_c_df["客户允许卸货的时间窗口"] = order_c_df["客户允许卸货的时间窗口"].astype("str")
order_c_df["最长送达时间(小时)"] = order_c_df["最长送达时间(小时)"].astype("float")
order_c_df["卸货周期（星期几可以收货）"] = order_c_df["卸货周期（星期几可以收货）"].astype("str")

# %%
order_c_df.head(1)
# Out:
#         订单编号  客户编号    地址编号  收货省 收货市  收货区                 目的地省市区详细地址  \
# 0  812834867  A001  低温阳信润丰  山东省  阳信  NaN  山东省滨州市阳信县信城街道办事处劳家小庄村中段路西
#
#            经度         纬度 温控类型  ...    客户名称  客户等级       客户允许的可用车型  客户允许卸货的时间窗口  \
# 0  117.435735  37.627133   冷藏  ...  低温阳信润丰   NaN  4.2米、6.8米、9.6米   8:00-18:00
#
#   最长送达时间(小时) 卸货周期（星期几可以收货）       发货波次              创建时间      地址编码  \
# 0  14.154167         周一-周日  3：00-7：00  2025-03-14T05:57  DZ000001
#
#          客户允许的可用车型编码
# 0  Type7,Type6,Type5
#
# [1 rows x 22 columns]

# %%
def order_detail_generate(orderNo):
    orderNo="1"
    # 生成奶粉的 SKU 信息
    NF_sku_details_info = {}
    for i in range(1, 21):
        sku_code = f"NF{str(i).zfill(4)}"
        NF_sku_details_info[sku_code] = {
            "skuDescr1": "奶粉"+str(i),
            "weight": 1000,
            "cubic": 0.0017,
            "temperatureType": "常温",
            "grossWeight": 800,
            "cube": 0.0015
        }

    # 生成酸奶的 SKU 信息
    SN_sku_details_info = {}
    for i in range(1, 21):
        sku_code = f"NF{str(i).zfill(4)}"
        if i < 10:
            SN_sku_details_info[sku_code] = {
                "skuDescr1": "酸奶"+str(i),
                "weight": 320,
                "cubic": 0.0003,
                "temperatureType": "常温",
                "grossWeight": 300,
                "cube": 0.0003
            }
        elif 10 < i < 15:
            SN_sku_details_info[sku_code] = {
                "skuDescr1": "酸奶"+str(i),
                "weight": 182,
                "cubic": 0.00017,
                "temperatureType": "冷藏",
                "grossWeight": 180,
                "cube": 0.00017
            }
        elif i > 15:
            SN_sku_details_info[sku_code] = {
                "skuDescr1": "酸奶"+str(i),
                "weight": 205,
                "cubic": 0.00019,
                "temperatureType": "常温",
                "grossWeight": 200,
                "cube": 0.00019
            }

    # 合并奶粉和酸奶的 SKU 信息
    all_sku_details_info = {**NF_sku_details_info, **SN_sku_details_info}
    # 订单上限
    MAX_SKU_COUNT = 500
    MIN_WEIGHT = 400000
    MAX_WEIGHT = 3000000

    current_order = {}
    current_sku_count = 0
    current_weight = 0
    available_skus = list(all_sku_details_info.keys())

    while available_skus:
        # 随机选择一个 SKU
        sku = random.choice(available_skus)
        weight = int(all_sku_details_info[sku]["weight"])
        RANDOM_SKU_COUNT = random.randint(100, MAX_SKU_COUNT)
        # 检查加入该 SKU 后是否会超过 SKU 件数上限和总重量上限
        if current_sku_count <= RANDOM_SKU_COUNT:
            if sku in current_order:
                current_order[sku] += 1
            else:
                current_order[sku] = 1
            current_sku_count += 1
            current_weight += weight
        else:
            break
    order_detail_list = list()
    for index, (sku, count) in enumerate(current_order.items()):
        order_detail_list.append({"taskNo":orderNo, "taskLineNo": str(index+1),
                            "sku": sku, 
                            "skuDescr1": all_sku_details_info[sku]['skuDescr1'],
                            "qty": count,
                            "weight" : round(count*all_sku_details_info[sku]['weight']/ 1_000_000,5),
                            "cubic" : round(count*all_sku_details_info[sku]['cubic'],5),
                            "temperatureType" : all_sku_details_info[sku]['temperatureType'],
                            "grossWeight" : round(count*all_sku_details_info[sku]['grossWeight']/ 1_000_000,5),
                            "cube" : round(count*all_sku_details_info[sku]['cube'],5)
                            })
        qty = sum(sku["qty"] for sku in order_detail_list)
        weight =  sum(sku["weight"]*sku["qty"] for sku in order_detail_list)
        cubic = sum(sku["cubic"]*sku["qty"] for sku in order_detail_list)
    return qty, round(weight,3), round(cubic,3), order_detail_list

def get_time_complement(time_str):
    # 将时间字符串拆分成时间区间列表
    intervals = [interval.split('-') for interval in time_str.split(',')]
    # 初始化补集区间列表
    complement_intervals = []
    # 前一个区间的结束时间，初始为 00:00
    prev_end = '00:00'

    for start, end in intervals:
        if start > prev_end:
            # 如果当前区间的开始时间大于前一个区间的结束时间，说明存在空闲区间
            complement_intervals.append(f"{prev_end}-{start}")
        # 更新前一个区间的结束时间
        prev_end = end

    # 检查最后一个区间结束后到 24:00 是否有空闲区间
    if prev_end < '24:00':
        complement_intervals.append(f"{prev_end}-24:00")

    # 将补集区间列表转换为字符串
    return ','.join(complement_intervals)

# %%
order_c_df.columns
# Out:
# Index(['订单编号', '客户编号', '地址编号', '收货省', '收货市', '收货区', '目的地省市区详细地址', '经度', '纬度',
#        '温控类型', '订单总重量（吨）', '订单总体积（立方米）', '客户名称', '客户等级', '客户允许的可用车型',
#        '客户允许卸货的时间窗口', '最长送达时间(小时)', '卸货周期（星期几可以收货）', '发货波次', '创建时间', '地址编码',
#        '客户允许的可用车型编码'],
#       dtype='object')

# %%
orders_list = list()
for index, orders_info in order_c_df.iterrows():
    order = dict()
    order["dispatchZoneCode"] = dispatchZone_list[0]["dispatchZoneCode"]
    order["taskNo"] = orders_info["订单编号"]
    order["orderNo"] = orders_info["订单编号"]
    order["DC"] = depots_list[0]["branchId"]
    order["createTime"] = orders_info["创建时间"]
    order["routeNoNext"] = "",
    order["offeringType"] = "汽运"
    order["temperatureClass"] = orders_info['温控类型']
    order["addressNo"] = orders_info['地址编码']
    order["address"] = orders_info['目的地省市区详细地址']
    order["vehicleCategory"] = ','.join([vehicleType["vehicleTypeId"] for dispatchZone in dispatchZone_list if dispatchZone["dispatchZoneCode"] == dispatchZone_list[0]["dispatchZoneCode"] for vehicleType in dispatchZone["vehicleType"]])
    order["longitude"] = orders_info["经度"]
    order["latitude"] = orders_info["纬度"]
    order["consigneeId"] = orders_info["客户编号"]
    order["companyClass"] = ""
    order["availableVehicleType"] = orders_info["客户允许的可用车型编码"]
    order["vehicleCategoryCus"] = ','.join(set(order["vehicleCategory"].split(',')).intersection(set(order["availableVehicleType"].split(','))))
    order["unloadingTimeWindow"] = orders_info["客户允许卸货的时间窗口"]
    order["nonunloadingTimeWindow"] = get_time_complement(orders_info["客户允许卸货的时间窗口"])
    order["leadTime"] = orders_info['最长送达时间(小时)']
    datedic = {'周一': 1, '周二': 2, '周三': 3, '周四': 4, '周五': 5, '周六': 6, '周日': 7}
    order["SDD"] = (','.join(str(i) for i in range(datedic[orders_info['卸货周期（星期几可以收货）'].split('-')[0]], 
                                                   datedic[orders_info['卸货周期（星期几可以收货）'].split('-')[1]] + 1)))
    order["qty"], order["weight"], order["cubic"], order["order_detail_list"] = order_detail_generate(order["orderNo"])

# %%
order
# Out:
# {'dispatchZoneCode': 'DISZONE001',
#  'taskNo': '802835386',
#  'orderNo': '802835386',
#  'DC': 'R005',
#  'createTime': '2025-03-14T20:33',
#  'routeNoNext': ('',),
#  'offeringType': '汽运',
#  'temperatureClass': '常温',
#  'addressNo': 'DZ000036',
#  'address': '路7号 山东省青岛市城阳区北部工业园祺阳',
#  'vehicleCategory': 'Type1,Type2,Type3,Type4,Type5,Type6,Type7,Type8',
#  'longitude': 120.240996610331,
#  'latitude': 36.2604603611225,
#  'consigneeId': 'A069',
#  'companyClass': '',
#  'availableVehicleType': 'Type3,Type2,Type1',
#  'vehicleCategoryCus': 'Type3,Type1,Type2',
#  'unloadingTimeWindow': '8:00-17:00',
#  'nonunloadingTimeWindow': '00:00-8:00,17:00-24:00',
#  'leadTime': 37.1911111111403,
#  'SDD': '1,2,3,4,5,6,7',
#  'qty': 115,
#  'weight': 0.256,
#  'cubic': 0.314,
#  'order_detail_list': [{'taskNo': '1',
#    'taskLineNo': '1',
#    'sku': 'NF0004',
#    'skuDescr1': '酸奶4',
#    'qty': 8,
#    'weight': 0.00256,
#    'cubic': 0.0024,
#    'temperatureType': '常温',
#    'grossWeight': 0.0024,
#    'cube': 0.0024},
#   {'taskNo': '1',
#    'taskLineNo': '2',
#    'sku': 'NF0017',
#    'skuDescr1': '酸奶17',
#    'qty': 6,
#    'weight': 0.00123,
#    'cubic': 0.00114,
#    'temperatureType': '常温',
#    'grossWeight': 0.0012,
#    'cube': 0.00114},
#   {'taskNo': '1',
#    'taskLineNo': '3',
#    'sku': 'NF0020',
#    'skuDescr1': '酸奶20',
#    'qty': 7,
#    'weight': 0.00144,
#    'cubic': 0.00133,
#    'temperatureType': '常温',
#    'grossWeight': 0.0014,
#    'cube': 0.00133},
#   {'taskNo': '1',
#    'taskLineNo': '4',
#    'sku': 'NF0011',
#    'skuDescr1': '酸奶11',
#    'qty': 9,
#    'weight': 0.00164,
#    'cubic': 0.00153,
#    'temperatureType': '冷藏',
#    'grossWeight': 0.00162,
#    'cube': 0.00153},
#   {'taskNo': '1',
#    'taskLineNo': '5',
#    'sku': 'NF0005',
#    'skuDescr1': '酸奶5',
#    'qty': 6,
#    'weight': 0.00192,
#    'cubic': 0.0018,
#    'temperatureType': '常温',
#    'grossWeight': 0.0018,
#    'cube': 0.0018},
#   {'taskNo': '1',
#    'taskLineNo': '6',
#    'sku': 'NF0015',
#    'skuDescr1': '奶粉15',
#    'qty': 9,
#    'weight': 0.009,
#    'cubic': 0.0153,
#    'temperatureType': '常温',
#    'grossWeight': 0.0072,
#    'cube': 0.0135},
#   {'taskNo': '1',
#    'taskLineNo': '7',
#    'sku': 'NF0003',
#    'skuDescr1': '酸奶3',
#    'qty': 7,
#    'weight': 0.00224,
#    'cubic': 0.0021,
#    'temperatureType': '常温',
#    'grossWeight': 0.0021,
#    'cube': 0.0021},
#   {'taskNo': '1',
#    'taskLineNo': '8',
#    'sku': 'NF0010',
#    'skuDescr1': '奶粉10',
#    'qty': 4,
#    'weight': 0.004,
#    'cubic': 0.0068,
#    'temperatureType': '常温',
#    'grossWeight': 0.0032,
#    'cube': 0.006},
#   {'taskNo': '1',
#    'taskLineNo': '9',
#    'sku': 'NF0007',
#    'skuDescr1': '酸奶7',
#    'qty': 6,
#    'weight': 0.00192,
#    'cubic': 0.0018,
#    'temperatureType': '常温',
#    'grossWeight': 0.0018,
#    'cube': 0.0018},
#   {'taskNo': '1',
#    'taskLineNo': '10',
#    'sku': 'NF0012',
#    'skuDescr1': '酸奶12',
#    'qty': 7,
#    'weight': 0.00127,
#    'cubic': 0.00119,
#    'temperatureType': '冷藏',
#    'grossWeight': 0.00126,
#    'cube': 0.00119},
#   {'taskNo': '1',
#    'taskLineNo': '11',
#    'sku': 'NF0014',
#    'skuDescr1': '酸奶14',
#    'qty': 5,
#    'weight': 0.00091,
#    'cubic': 0.00085,
#    'temperatureType': '冷藏',
#    'grossWeight': 0.0009,
#    'cube': 0.00085},
#   {'taskNo': '1',
#    'taskLineNo': '12',
#    'sku': 'NF0019',
#    'skuDescr1': '酸奶19',
#    'qty': 5,
#    'weight': 0.00103,
#    'cubic': 0.00095,
#    'temperatureType': '常温',
#    'grossWeight': 0.001,
#    'cube': 0.00095},
#   {'taskNo': '1',
#    'taskLineNo': '13',
#    'sku': 'NF0013',
#    'skuDescr1': '酸奶13',
#    'qty': 3,
#    'weight': 0.00055,
#    'cubic': 0.00051,
#    'temperatureType': '冷藏',
#    'grossWeight': 0.00054,
#    'cube': 0.00051},
#   {'taskNo': '1',
#    'taskLineNo': '14',
#    'sku': 'NF0008',
#    'skuDescr1': '酸奶8',
#    'qty': 4,
#    'weight': 0.00128,
#    'cubic': 0.0012,
#    'temperatureType': '常温',
#    'grossWeight': 0.0012,
#    'cube': 0.0012},
#   {'taskNo': '1',
#    'taskLineNo': '15',
#    'sku': 'NF0006',
#    'skuDescr1': '酸奶6',
#    'qty': 7,
#    'weight': 0.00224,
#    'cubic': 0.0021,
#    'temperatureType': '常温',
#    'grossWeight': 0.0021,
#    'cube': 0.0021},
#   {'taskNo': '1',
#    'taskLineNo': '16',
#    'sku': 'NF0018',
#    'skuDescr1': '酸奶18',
#    'qty': 5,
#    'weight': 0.00103,
#    'cubic': 0.00095,
#    'temperatureType': '常温',
#    'grossWeight': 0.001,
#    'cube': 0.00095},
#   {'taskNo': '1',
#    'taskLineNo': '17',
#    'sku': 'NF0016',
#    'skuDescr1': '酸奶16',
#    'qty': 4,
#    'weight': 0.00082,
#    'cubic': 0.00076,
#    'temperatureType': '常温',
#    'grossWeight': 0.0008,
#    'cube': 0.00076},
#   {'taskNo': '1',
#    'taskLineNo': '18',
#    'sku': 'NF0009',
#    'skuDescr1': '酸奶9',
#    'qty': 5,
#    'weight': 0.0016,
#    'cubic': 0.0015,
#    'temperatureType': '常温',
#    'grossWeight': 0.0015,
#    'cube': 0.0015},
#   {'taskNo': '1',
#    'taskLineNo': '19',
#    'sku': 'NF0001',
#    'skuDescr1': '酸奶1',
#    'qty': 4,
#    'weight': 0.00128,
#    'cubic': 0.0012,
#    'temperatureType': '常温',
#    'grossWeight': 0.0012,
#    'cube': 0.0012},
#   {'taskNo': '1',
#    'taskLineNo': '20',
#    'sku': 'NF0002',
#    'skuDescr1': '酸奶2',
#    'qty': 4,
#    'weight': 0.00128,
#    'cubic': 0.0012,
#    'temperatureType': '常温',
#    'grossWeight': 0.0012,
#    'cube': 0.0012}]}
